# %% [markdown]
# # Phase 1: Data Generation
# This notebook generates synthetic student records for Caraga State University.

# %%
import sys
sys.path.append("..")
from src.generator import CSUDataGenerator
import os

# %%
gen = CSUDataGenerator()
df_students = gen.generate_students(800)
df_academic = gen.generate_academic_records(df_students)
df_financial = gen.generate_financials(df_students)

os.makedirs("../data/raw", exist_ok=True)
df_students.to_csv("../data/raw/students_raw.csv", index=False)
df_academic.to_csv("../data/raw/academic_records_raw.csv", index=False)
df_financial.to_csv("../data/raw/financial_info_raw.csv", index=False)

print("Data Generated and saved to data/raw/")
df_students.head()
# Out:
# Data Generated and saved to data/raw/
#       student_id  last_name first_name     sex   age  \
# 0  CSU-2021-1000      Baker    Jessica  Female  20.0
# 1  CSU-2021-1001      Yoder    Richard    Male  26.0
# 2  CSU-2021-1002  Whitehead    Michael    Male  25.0
# 3  CSU-2021-1003  Gillespie     Daniel    Male  24.0
# 4  CSU-2021-1004       Khan    Melinda  Female  22.0
#
#                                          college                  course  \
# 0  College of Computing and Information Sciences     BS Computer Science
# 1  College of Computing and Information Sciences  BS Information Systems
# 2  College of Computing and Information Sciences     BS Computer Science
# 3                   College of Arts and Sciences          BS Mathematics
# 4  College of Computing and Information Sciences     BS Computer Science
#
#    year_level scholarship_type
# 0           2     CHED UniFAST
# 1           4     CHED UniFAST
# 2           1    LGU Sponsored
# 3           3             None
# 4           3     CHED UniFAST
