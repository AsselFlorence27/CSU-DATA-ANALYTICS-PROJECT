# %% [markdown]
# # Phase 4: Analysis & Visual Insights
# Visualizing scholarship risk and providing recommendations for university stakeholders.

# %%
import sys
sys.path.append("..")
from src.analyzer import CSUDataAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("../data/processed/csu_master_analytics.csv")
analyzer = CSUDataAnalyzer(df)

print("Scholarship Status Summary:")
print(analyzer.get_at_risk_summary())

# Visuals
analyzer.plot_income_vs_gpa()
plt.show()

analyzer.plot_status_by_college()
plt.show()

# %% [markdown]
# ## Recommendations
# 1. **Early Intervention**: Target students in the "Warning" category immediately via advisory programs.
# 2. **Financial Support**: Focus on low-income students with high academic potential to ensure long-term retention.
